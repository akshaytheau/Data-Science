# %%
# !pip install -q --upgrade git+https://github.com/huggingface/diffusers.git transformers accelerate scipy

# %%
import time
import warnings
import torch
from diffusers import StableDiffusionPipeline, EulerDiscreteScheduler

# %%
warnings.filterwarnings("ignore")

# %%
model_id = "stabilityai/stable-diffusion-2"
scheduler = EulerDiscreteScheduler.from_pretrained(model_id, 
                                                   subfolder="scheduler")

pipe = StableDiffusionPipeline.from_pretrained(model_id, 
                                               scheduler=scheduler, 
                                               revision="fp16", 
                                               torch_dtype=torch.float16)
pipe = pipe.to("cuda")
# Out:
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]

# %%
pipe("Turtle enjoying on beach", height=768, width=1024).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F0D5E82FB20>

# %%
pipe("Rabbit eating an apple", height=768, width=1024).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F0D5E774B80>
