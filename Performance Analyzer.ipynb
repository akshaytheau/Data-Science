# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("PerformanceAnalyzer.csv")

# %%
list1 = data.TestCaseID.to_list()

# %%
len(list1)
# Out:
# 776

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
data = pd.read_csv("PerformanceAnalyzer.csv")
data.plot(figsize=(30,30),fontsize=15,title='Performance Analyzer')
plt.xticks(np.arange(777), list1,rotation=90)
plt.xlabel('Test Case Ids',fontsize=15)
plt.ylabel('Time for execution',fontsize=15)
plt.show()

# %%
X = data['TestCaseID']
y = data['9-23-2020']
z = data['9-24-2020']

# %%
plt.plot(X,y)
