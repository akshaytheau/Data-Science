# %%
comments = pd.read_csv('YoutubeComments.csv')

# %%
comments
# Out:
#                                              Comments
# 0                          Super explanations so good
# 1                                                Good
# 2                                          Thankyou!!
# 3                            Excellent explanation...
# 4                                                Nice
# 5                                              Wowwww
# 6                 It was very clear and useful .....
# 7                 Very helpful and easy to understand
# 8                                    Super video bhai
# 9   Thank you so much bro. Excellent explanation. ...
# 10                              ek number explanation
# 11  I like your teaching skill and use 3 paper for...
# 12                                   Thanking you sir
# 13                               Love you thinks bor
# 14                      you saved my semester thnx :D
# 15                                  good job bro.....
# ...

# %%
word_collection = " "
for i in comments.Comments:
    word_collection = word_collection + i

# %%
print(word_collection)
# Out:
#  Super explanations so goodGoodThankyou!!Excellent explanation...NiceWowwwwIt was very clear and useful ..... Very helpful and easy to understandSuper video bhaiThank you so much bro. Excellent explanation. Absolutely superb. keep it upek number explanationI like your teaching skill and use 3 paper for each concept if any help for YouTube views then send me mailThanking you sirLove you thinks bor you saved my semester thnx :Dgood job bro.....Ek number explanationWrongVery raw , need improvementThe best ever seenThis just too goodWow you are the bestSimple and elegant explanationGrt explanationnicegood job bro.....Very goodToo grtNice videoKeept it up

# %%
from wordcloud import WordCloud
wordcloud = WordCloud().generate(word_collection)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud.to_file("ASboothscomment.png")
