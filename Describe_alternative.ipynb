# %%
import pandas as pd
import numpy as np

# %%
from skimpy import skim , generate_test_data

# %%
data = generate_test_data()

# %%
data.head()
# Out:
#      length     width  depth       rnd       class location  booly_col  \
# 0  0.762796  1.468082      9 -0.423534  virtginica       UK      False
# 1  0.031203  0.267769     10  2.102890  virtginica       UK      False
# 2  0.044075  3.571043     12  0.147606      setosa       UK       True
# 3  0.914088  2.838664     15 -0.997567  virtginica      NaN       True
# 4  0.555878  2.214629      5  0.329828      setosa       UK      False
#
#             text       date date_no_freq time diff
# 0  What weather! 2018-01-31          NaT    5 days
# 1   How are you? 2018-02-28   1992-01-05       NaT
# 2   How are you? 2018-03-31   2022-01-01    7 days
# 3           <NA> 2018-04-30          NaT    7 days
# 4   How are you? 2018-05-31   2022-01-01   13 days

# %%
data.describe()
# Out:
#             length        width        depth         rnd  \
# count  1000.000000  1000.000000  1000.000000  882.000000
# mean      0.501619     2.036549    10.024000   -0.019771
# min       0.000002     0.002057     2.000000   -2.808934
# 25%       0.134014     0.602987     8.000000   -0.735467
# 50%       0.497570     1.467916    10.000000   -0.000774
# 75%       0.860224     2.952881    12.000000    0.663878
# max       0.999999    13.908001    20.000000    3.716621
# std       0.359707     1.928640     3.208382    1.001654
#
#                              date                   date_no_freq  \
# count                        1000                            997
# mean   2059-09-15 03:05:45.600000  2012-03-18 11:07:16.910732288
# min           2018-01-31 00:00:00            1992-01-05 00:00:00
# 25%           2038-11-22 12:00:00            1992-01-05 00:00:00
# 50%           2059-09-15 00:00:00            2022-01-01 00:00:00
# 75%           2080-07-07 18:00:00            2023-03-04 00:00:00
# max           2101-04-30 00:00:00            2023-03-04 00:00:00
# std                           NaN                            NaN
#
#                        time diff
# count                        995
# mean   8 days 00:05:47.336683417
# min              0 days 00:00:00
# 25%              5 days 00:00:00
# 50%              6 days 00:00:00
# 75%              9 days 12:00:00
# max             26 days 00:00:00
# std    5 days 01:04:53.780972134

# %%
#df3 = generate_test_data()
skim(pd.DataFrame(data))
# Out:
# issue1
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types               Categories                                        │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓ ┏━━━━━━━━━━━━━━━━━━━━━━━┓                                │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃ ┃ Categorical Variables ┃                                │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩ ┡━━━━━━━━━━━━━━━━━━━━━━━┩                                │
# │ │ Number of rows    │ 1000   │ │ float64     │ 3     │ │ class                 │                                │
# │ │ Number of columns │ 11     │ │ category    │ 2     │ │ location              │                                │
# │ └───────────────────┴────────┘ │ datetime64  │ 2     │ └───────────────────────┘                                │
# │                                │ int64       │ 1     │                                                          │
# │                                │ bool        │ 1     │                                                          │
# │                                │ string      │ 1     │                                                          │
# │                                │ timedelta64 │ 1     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┓  │
# │ ┃ column_name      ┃ NA    ┃ NA %    ┃ mean     ┃ sd     ┃ p0         ┃ p25      ┃ p75    ┃ p100   ┃ hist    ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━━┩  │
# │ │ length           │     0 │       0 │      0.5 │   0.36 │    1.6e-06 │     0.13 │   0.86 │      1 │ █▃▃▃▄█  │  │
# │ │ width            │     0 │       0 │        2 │    1.9 │     0.0021 │      0.6 │      3 │     14 │   █▃▁   │  │
# │ │ depth            │     0 │       0 │       10 │    3.2 │          2 │        8 │     12 │     20 │ ▁▄█▆▃▁  │  │
# │ │ rnd              │   118 │    11.8 │    -0.02 │      1 │       -2.8 │    -0.74 │   0.66 │    3.7 │  ▁▄█▅▁  │  │
# │ └──────────────────┴───────┴─────────┴──────────┴────────┴────────────┴──────────┴────────┴────────┴─────────┘  │
# │                                                    category                                                     │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name                      ┃ NA        ┃ NA %           ┃ ordered               ┃ unique             ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ class                            │         0 │              0 │ False                 │                  2 │  │
# │ │ location                         │         1 │            0.1 │ False                 │                  5 │  │
# │ └──────────────────────────────────┴───────────┴────────────────┴───────────────────────┴────────────────────┘  │
# │                                                    datetime                                                     │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name             ┃ NA    ┃ NA %      ┃ first               ┃ last                ┃ frequency        ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩  │
# │ │ date                    │     0 │         0 │     2018-01-31      │     2101-04-30      │ M                │  │
# │ │ date_no_freq            │     3 │       0.3 │     1992-01-05      │     2023-03-04      │ None             │  │
# │ └─────────────────────────┴───────┴───────────┴─────────────────────┴─────────────────────┴──────────────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name               ┃ NA      ┃ NA %       ┃ words per row                ┃ total words              ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ text                      │       6 │        0.6 │                          5.8 │                     5761 │  │
# │ └───────────────────────────┴─────────┴────────────┴──────────────────────────────┴──────────────────────────┘  │
# │                                                      bool                                                       │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name                        ┃ true            ┃ true rate                     ┃ hist                ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ booly_col                          │             516 │                          0.52 │       █    █        │  │
# │ └────────────────────────────────────┴─────────────────┴───────────────────────────────┴─────────────────────┘  │
# │                                                  timedelta64                                                    │
# │ ┏━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name     ┃ NA   ┃ NA %   ┃ mean                       ┃ median               ┃ max                  ┃  │
# │ ┡━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ time diff       │    5 │    0.5 │  8 days 00:05:47.336683417 │      0 days 00:00:00 │     26 days 00:00:00 │  │
# │ └─────────────────┴──────┴────────┴────────────────────────────┴──────────────────────┴──────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
df3.describe(include='all')
# Out:
#              length        width        depth         rnd       class  \
# count   1000.000000  1000.000000  1000.000000  882.000000        1000
# unique          NaN          NaN          NaN         NaN           2
# top             NaN          NaN          NaN         NaN  virtginica
# freq            NaN          NaN          NaN         NaN         514
# mean       0.501619     2.036549    10.024000   -0.019771         NaN
# min        0.000002     0.002057     2.000000   -2.808934         NaN
# 25%        0.134014     0.602987     8.000000   -0.735467         NaN
# 50%        0.497570     1.467916    10.000000   -0.000774         NaN
# 75%        0.860224     2.952881    12.000000    0.663878         NaN
# max        0.999999    13.908001    20.000000    3.716621         NaN
# std        0.359707     1.928640     3.208382    1.001654         NaN
#
#        location booly_col                                               text  \
# count       999      1000                                                994
# unique        4         2                                                  3
# top          UK      True  Indeed, it was the most outrageously pompous c...
# freq        606       516                                                346
# mean        NaN       NaN                                                NaN
# min         NaN       NaN                                                NaN
# 25%         NaN       NaN                                                NaN
# 50%         NaN       NaN                                                NaN
# 75%         NaN       NaN                                                NaN
# max         NaN       NaN                                                NaN
# std         NaN       NaN                                                NaN
#
#                               date                   date_no_freq  \
# count                         1000                            997
# unique                         NaN                            NaN
# top                            NaN                            NaN
# freq                           NaN                            NaN
# mean    2059-09-15 03:05:45.600000  2012-03-18 11:07:16.910732288
# min            2018-01-31 00:00:00            1992-01-05 00:00:00
# 25%            2038-11-22 12:00:00            1992-01-05 00:00:00
# 50%            2059-09-15 00:00:00            2022-01-01 00:00:00
# 75%            2080-07-07 18:00:00            2023-03-04 00:00:00
# max            2101-04-30 00:00:00            2023-03-04 00:00:00
# std                            NaN                            NaN
#
#                         time diff
# count                         995
# unique                        NaN
# top                           NaN
# freq                          NaN
# mean    8 days 00:05:47.336683417
# min               0 days 00:00:00
# 25%               5 days 00:00:00
# 50%               6 days 00:00:00
# 75%               9 days 12:00:00
# max              26 days 00:00:00
# std     5 days 01:04:53.780972134

# %%
! pip install summarytools
# Out:
# Collecting summarytools
#   Downloading summarytools-0.2.3.tar.gz (11 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from summarytools) (2.0.3)
# Requirement already satisfied: ipython>=7.20.0 in /usr/local/lib/python3.10/dist-packages (from summarytools) (7.34.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from summarytools) (1.22.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from summarytools) (3.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.20.0->summarytools) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.20.0->summarytools) (0.19.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=7.20.0->summarytools) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=7.20.0->summarytools) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.20.0->summarytools) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.20.0->summarytools) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=7.20.0->summarytools) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=7.20.0->summarytools) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=7.20.0->summarytools) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.20.0->summarytools) (4.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->summarytools) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->summarytools) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->summarytools) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->summarytools) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->summarytools) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->summarytools) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->summarytools) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->summarytools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->summarytools) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->summarytools) (2023.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=7.20.0->summarytools) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=7.20.0->summarytools) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.20.0->summarytools) (0.2.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->summarytools) (1.16.0)
# Building wheels for collected packages: summarytools
#   Building wheel for summarytools (pyproject.toml) ... done
#   Created wheel for summarytools: filename=summarytools-0.2.3-py3-none-any.whl size=8571 sha256=f781b96e196e08e770e02e37ffa88b283c027eb6944e08b7d13da9c9f64f1271
#   Stored in directory: /root/.cache/pip/wheels/d5/8a/5d/008e2127a7f9dd64d066f16e5ea268fa52823dc929c982d6f1
# Successfully built summarytools
# Installing collected packages: summarytools
# Successfully installed summarytools-0.2.3

# %%
from summarytools import dfSummary

# %%
dfSummary(data, is_collapsible = True)
# Out:
# <button type="button" class = "st-collapsible",
#     id = "btn-5064" onclick = "coll_toggle_5064()">Show Summary - data</button>
#     <div class="st-content" id="cont-5064">
#       <style type="text/css">
# #T_d9001 thead>tr>th {
#   text-align: left;
# }
# #T_d9001_row0_col0, #T_d9001_row1_col0, #T_d9001_row2_col0, #T_d9001_row3_col0, #T_d9001_row4_col0, #T_d9001_row5_col0, #T_d9001_row6_col0, #T_d9001_row7_col0, #T_d9001_row8_col0, #T_d9001_row9_col0, #T_d9001_row10_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_d9001_row0_col1, #T_d9001_row1_col1, #T_d9001_row2_col1, #T_d9001_row3_col1, #T_d9001_row4_col1, #T_d9001_row5_col1, #T_d9001_row6_col1, #T_d9001_row7_col1, #T_d9001_row8_col1, #T_d9001_row9_col1, #T_d9001_row10_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_d9001_row0_col2, #T_d9001_row1_col2, #T_d9001_row2_col2, #T_d9001_row3_col2, #T_d9001_row4_col2, #T_d9001_row5_col2, #T_d9001_row6_col2, #T_d9001_row7_col2, #T_d9001_row8_col2, #T_d9001_row9_col2, #T_d9001_row10_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_d9001_row0_col3, #T_d9001_row1_col3, #T_d9001_row2_col3, #T_d9001_row3_col3, #T_d9001_row4_col3, #T_d9001_row5_col3, #T_d9001_row6_col3, #T_d9001_row7_col3, #T_d9001_row8_col3, #T_d9001_row9_col3, #T_d9001_row10_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_d9001_row0_col4, #T_d9001_row1_col4, #T_d9001_row2_col4, #T_d9001_row3_col4, #T_d9001_row4_col4, #T_d9001_row5_col4, #T_d9001_row6_col4, #T_d9001_row7_col4, #T_d9001_row8_col4, #T_d9001_row9_col4, #T_d9001_row10_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_d9001_row0_col5, #T_d9001_row1_col5, #T_d9001_row2_col5, #T_d9001_row3_col5, #T_d9001_row4_col5, #T_d9001_row5_col5, #T_d9001_row6_col5, #T_d9001_row7_col5, #T_d9001_row8_col5, #T_d9001_row9_col5, #T_d9001_row10_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_d9001">
#   <caption><strong>Data Frame Summary</strong><br>data<br>Dimensions: 1,000 x 11<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_d9001_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_d9001_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_d9001_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_d9001_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_d9001_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_d9001_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d9001_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_d9001_row0_col1" class="data row0 col1" ><strong>length</strong><br>[float64]</td>
#       <td id="T_d9001_row0_col2" class="data row0 col2" >Mean (sd) : 0.5 (0.4)<br>min < med < max:<br>0.0 < 0.5 < 1.0<br>IQR (CV) : 0.7 (1.4)</td>
#       <td id="T_d9001_row0_col3" class="data row0 col3" >1,000 distinct values</td>
#       <td id="T_d9001_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_d9001_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_d9001_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_d9001_row1_col1" class="data row1 col1" ><strong>width</strong><br>[float64]</td>
#       <td id="T_d9001_row1_col2" class="data row1 col2" >Mean (sd) : 2.0 (1.9)<br>min < med < max:<br>0.0 < 1.5 < 13.9<br>IQR (CV) : 2.3 (1.1)</td>
#       <td id="T_d9001_row1_col3" class="data row1 col3" >1,000 distinct values</td>
#       <td id="T_d9001_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_d9001_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_d9001_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_d9001_row2_col1" class="data row2 col1" ><strong>depth</strong><br>[int64]</td>
#       <td id="T_d9001_row2_col2" class="data row2 col2" >Mean (sd) : 10.0 (3.2)<br>min < med < max:<br>2.0 < 10.0 < 20.0<br>IQR (CV) : 4.0 (3.1)</td>
#       <td id="T_d9001_row2_col3" class="data row2 col3" >19 distinct values</td>
#       <td id="T_d9001_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_d9001_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_d9001_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_d9001_row3_col1" class="data row3 col1" ><strong>rnd</strong><br>[float64]</td>
#       <td id="T_d9001_row3_col2" class="data row3 col2" >Mean (sd) : -0.0 (1.0)<br>min < med < max:<br>-2.8 < -0.0 < 3.7<br>IQR (CV) : 1.4 (-0.0)</td>
#       <td id="T_d9001_row3_col3" class="data row3 col3" >882 distinct values</td>
#       <td id="T_d9001_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_d9001_row3_col5" class="data row3 col5" >118<br>(11.8%)</td>
#     </tr>
#     <tr>
#       <td id="T_d9001_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_d9001_row4_col1" class="data row4 col1" ><strong>class</strong><br>[category]</td>
#       <td id="T_d9001_row4_col2" class="data row4 col2" >1. virtginica<br>2. setosa</td>
#       <td id="T_d9001_row4_col3" class="data row4 col3" >514 (51.4%)<br>486 (48.6%)</td>
#       <td id="T_d9001_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_d9001_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_d9001_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_d9001_row5_col1" class="data row5 col1" ><strong>location</strong><br>[category]</td>
#       <td id="T_d9001_row5_col2" class="data row5 col2" >1. UK<br>2. Mexico<br>3. India<br>4. USA<br>5. nan</td>
#       <td id="T_d9001_row5_col3" class="data row5 col3" >606 (60.6%)<br>199 (19.9%)<br>108 (10.8%)<br>86 (8.6%)<br>1 (0.1%)</td>
#       <td id="T_d9001_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_d9001_row5_col5" class="data row5 col5" >1<br>(0.1%)</td>
#     </tr>
#     <tr>
#       <td id="T_d9001_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_d9001_row6_col1" class="data row6 col1" ><strong>booly_col</strong><br>[bool]</td>
#       <td id="T_d9001_row6_col2" class="data row6 col2" >1. True<br>2. False</td>
#       <td id="T_d9001_row6_col3" class="data row6 col3" >516 (51.6%)<br>484 (48.4%)</td>
#       <td id="T_d9001_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_d9001_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_d9001_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_d9001_row7_col1" class="data row7 col1" ><strong>text</strong><br>[string]</td>
#       <td id="T_d9001_row7_col2" class="data row7 col2" >not supported dtype string</td>
#       <td id="T_d9001_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_d9001_row7_col4" class="data row7 col4" >nan</td>
#       <td id="T_d9001_row7_col5" class="data row7 col5" >6<br>(0.6%)</td>
#     </tr>
#     <tr>
#       <td id="T_d9001_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_d9001_row8_col1" class="data row8 col1" ><strong>date</strong><br>[datetime64[ns]]</td>
#       <td id="T_d9001_row8_col2" class="data row8 col2" >Min: 2018-01-31<br>Max: 2101-04-30<br>Duration: 30,404 days</td>
#       <td id="T_d9001_row8_col3" class="data row8 col3" >1000 distinct values</td>
#       <td id="T_d9001_row8_col4" class="data row8 col4" ><img src = "......"></img></td>
#       <td id="T_d9001_row8_col5" class="data row8 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_d9001_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_d9001_row9_col1" class="data row
